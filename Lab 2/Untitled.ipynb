# %%
! gcc -c -Wall -Werror -fpic main.c
! gcc -shared -o libMyLib.so main.o
# Out:
# main.c: In function ‘myMultiply’:
# main.c:9:15: error: ‘time’ undeclared (first use in this function)
#     9 |         sleep(time);
#       |               ^~~~
# main.c:9:15: note: each undeclared identifier is reported only once for each function it appears in
# main.c: At top level:
# main.c:13:5: error: conflicting types for ‘myAdd’; have ‘int(int,  int,  double)’
#    13 | int myAdd(int a, int b, double time){
#       |     ^~~~~
# main.c:3:5: note: previous definition of ‘myAdd’ with type ‘int(int,  int)’
#     3 | int myAdd(int a, int b){
#       |     ^~~~~
# main.c:18:5: error: conflicting types for ‘myMultiply’; have ‘int(int,  int,  double)’
#    18 | int myMultiply(int a, int b, double time){
#       |     ^~~~~~~~~~
# main.c:8:5: note: previous definition of ‘myMultiply’ with type ‘int(int,  int)’
#     8 | int myMultiply(int a, int b){
#       |     ^~~~~~~~~~
